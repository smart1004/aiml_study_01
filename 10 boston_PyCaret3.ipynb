# %% [markdown]
# https://www.kaggle.com/debanga/introduction-to-pycaret

# %% [markdown]
# pycaret boston

# %%
import pycaret

# %%
dir(pycaret)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'utils']

# %%
pycaret.__version__
# Out:
# '2.3.5'

# %% [raw]
# # from pycaret import regression as reg
# # dir(reg)
#
# book
# https://www.kaggle.com/debanga/introduction-to-pycaret
# from pycaret.regression import *
# Code
# pycaret boston

# %%
import pycaret
pycaret
# dir(pycaret)
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__']

from pycaret.regression import *

# %%
pycaret.__version__
# Out:
# '2.3.5'

# %%
# Loading data from pycaret
from pycaret.datasets import get_data
boston = get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston.tax.value_counts()
# Out:
# 666    132
# 307     40
# 403     30
# 437     15
# 304     14
# 264     12
# 398     12
# 384     11
# 277     11
# 224     10
# 330     10
# 432      9
# 233      9
# 276      9
# 296      8
# 193      8
# 287      8
# 391      8
# 300      7
# 284      7
# 270      7
# 188      7
# 311      7
# 222      7
# 329      6
# 254      5
# 289      5
# 711      5
# 223      5
# 273      5
# 216      5
# 243      4
# 247      4
# 281      4
# 305      4
# 279      4
# 293      3
# 430      3
# 345      3
# 358      3
# 245      3
# 370      2
# 335      2
# 411      2
# 265      2
# 348      2
# 334      2
# 252      2
# 337      2
# 315      2
# 242      2
# 402      2
# 352      2
# 187      1
# 351      1
# 280      1
# 255      1
# 422      1
# 469      1
# 226      1
# 241      1
# 285      1
# 198      1
# 256      1
# 244      1
# 313      1
# Name: tax, dtype: int64

# %%
boston.chas.value_counts()
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
boston.rad.value_counts()
# Out:
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: rad, dtype: int64

# %%
type(boston)
# Out:
# pandas.core.frame.DataFrame

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
reg1 = setup(data = boston, 
             numeric_features =  ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
               'ptratio', 'black', 'lstat'],  
             categorical_features = ['chas'],
             target = 'medv',
            )
# Out:
# <style type="text/css">
# #T_a070b_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a070b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a070b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a070b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a070b_row0_col1" class="data row0 col1" >7393</td>
#     </tr>
#     <tr>
#       <th id="T_a070b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a070b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a070b_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_a070b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a070b_row2_col0" class="data row2 col0" >Original Data</td>
# ...

# %%
# comparing all models
compare_models()
# Out:
# <style type="text/css">
# #T_841de_ th {
#   text-align: left;
# }
# ...

# %%
# creating xgboost model
# xgboost = create_model('xgboost')

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_a64df_row10_col0, #T_a64df_row10_col1, #T_a64df_row10_col2, #T_a64df_row10_col3, #T_a64df_row10_col4, #T_a64df_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a64df_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a64df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a64df_row0_col0" class="data row0 col0" >3.8887</td>
#       <td id="T_a64df_row0_col1" class="data row0 col1" >31.0989</td>
#       <td id="T_a64df_row0_col2" class="data row0 col2" >5.5766</td>
# ...

# %%
# tuning Random Forest model
# tuned_rf = tune_model(rf, n_iter = 50, optimize = 'mae')
tuned_rf = tune_model(estimator=rf)
# Out:
# <style type="text/css">
# #T_a9f93_row10_col0, #T_a9f93_row10_col1, #T_a9f93_row10_col2, #T_a9f93_row10_col3, #T_a9f93_row10_col4, #T_a9f93_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a9f93_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9f93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9f93_row0_col0" class="data row0 col0" >3.3887</td>
#       <td id="T_a9f93_row0_col1" class="data row0 col1" >18.3420</td>
#       <td id="T_a9f93_row0_col2" class="data row0 col2" >4.2828</td>
# ...
